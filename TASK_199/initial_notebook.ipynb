# %%
#!/usr/bin/env python
# coding: utf-8

data = [
    ("A", 80, 2),
    ("B", 70, 3),
    ("A", 90, 1),
    ("C", 85, 2),
    ("A", 75, 4)
]

category = "A"

# Incorrect: includes all categories and ignores weights
scores = [score for _, score, _ in data]
average = sum(scores) / len(scores)

print("Average (incorrect):", average)
