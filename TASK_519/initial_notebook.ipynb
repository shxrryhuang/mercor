# %%
import numpy as np
from scipy.optimize import fsolve

def f(x):
    return np.cos(x) - x/2

def f_prime(x):
    return -np.sin(x) - 0.5

a, b = 0, 2
tolerance = 1e-6
max_iter = 50

exact_root = fsolve(f, 1)[0]
print(f"Exact root: {exact_root:.10f}")

# --- Bisection Method (Incorrect) ---
c = (a + b) / 2
for i in range(max_iter):
    if f(a) * f(c) < 0:
        b = c
    else:
        a = c
bisection_root = c  # <-- never updated correctly

print(f"Bisection Approximation: {bisection_root:.10f}")

# --- Newton-Raphson Method (Missing) ---
print("Newton-Raphson not implemented")

# --- Error calculations (Incomplete) ---
print("Error analysis incomplete")

# --- Convergence analysis (Missing) ---
print("Convergence analysis not implemented")
