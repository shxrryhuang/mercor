# %%
import pandas as pd
import numpy as np

# Product quality by factory
df = pd.DataFrame({
    "factory": ["A","A","A","B","B","B","C","C","C"],
    "quality_score": [80,82,85,78,77,79,90,92,91]
})

# Bug: calculates mean instead of std
factory_stats = df.groupby("factory")["quality_score"].mean()
highest_std_factory = factory_stats.idxmax()
print("Highest std factory (buggy):", highest_std_factory)
