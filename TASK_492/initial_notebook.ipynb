# %%
#!/usr/bin/env python
# coding: utf-8

import pandas as pd
import numpy as np

# Dataset of temperature vs energy consumption
df = pd.DataFrame({
    "temperature": [30, 32, 35, 37, 40, 42, 43, 45, 100, 47, 49, 50],
    "energy_usage": [200, 210, 215, 220, 230, 240, 245, 250, 800, 255, 260, 265]
})

# Incorrect: correlation computed before removing outliers
correlation = df["temperature"].corr(df["energy_usage"])

# Incorrect filtering threshold
filtered_df = df[df["temperature"] < 90]

average_energy = filtered_df["energy_usage"].mean()

print("Correlation (buggy):", correlation)
print("Average energy usage (buggy):", average_energy)
